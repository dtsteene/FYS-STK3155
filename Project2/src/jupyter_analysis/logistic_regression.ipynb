# %%
import jax.numpy as np
import numpy as onp
from ucimlrepo import fetch_ucirepo

# fetch dataset
breast_cancer_wisconsin_original = fetch_ucirepo(id=15)

# data (as pandas dataframes)
X_df = breast_cancer_wisconsin_original.data.features
y_df = breast_cancer_wisconsin_original.data.targets

# metadata
print(breast_cancer_wisconsin_original.metadata)

# variable information
print(breast_cancer_wisconsin_original.variables)

# Remove rows with missing values
nan_indexes = X_df[X_df.isna().any(axis=1)].index
X_df = X_df.drop(nan_indexes)
y_df = y_df.drop(nan_indexes)


# Convert DataFrames to numpy arrays
X = np.asarray(X_df.to_numpy(), dtype=float)
y = np.asarray(y_df.to_numpy() / 2 - 1.0)
# Out:
# {'uci_id': 15, 'name': 'Breast Cancer Wisconsin (Original)', 'repository_url': 'https://archive.ics.uci.edu/dataset/15/breast+cancer+wisconsin+original', 'data_url': 'https://archive.ics.uci.edu/static/public/15/data.csv', 'abstract': 'Original Wisconsin Breast Cancer Database', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 699, 'num_features': 9, 'feature_types': ['Integer'], 'demographics': [], 'target_col': ['Class'], 'index_col': ['Sample_code_number'], 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1990, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C5HP4Z', 'creators': ['WIlliam Wolberg'], 'intro_paper': None, 'additional_info': {'summary': "Samples arrive periodically as Dr. Wolberg reports his clinical cases. The database therefore reflects this chronological grouping of the data. This grouping information appears immediately below, having been removed from the data itself:\r\n\r\nGroup 1: 367 instances (January 1989)\r\nGroup 2:  70 instances (October 1989)\r\nGroup 3:  31 instances (February 1990)\r\nGroup 4:  17 instances (April 1990)\r\nGroup 5:  48 instances (August 1990)\r\nGroup 6:  49 instances (Updated January 1991)\r\nGroup 7:  31 instances (June 1991)\r\nGroup 8:  86 instances (November 1991)\r\n-----------------------------------------\r\nTotal:   699 points (as of the donated datbase on 15 July 1992)\r\n\r\nNote that the results summarized above in Past Usage refer to a dataset of size 369, while Group 1 has only 367 instances.  This is because it originally contained 369 instances; 2 were removed.  The following statements summarizes changes to the original Group 1's set of data:\r\n\r\n#####  Group 1 : 367 points: 200B 167M (January 1989)\r\n\r\n#####  Revised Jan 10, 1991: Replaced zero bare nuclei in 1080185 & 1187805\r\n\r\n#####  Revised Nov 22,1991: Removed 765878,4,5,9,7,10,10,10,3,8,1 no record\r\n#####                  : Removed 484201,2,7,8,8,4,3,10,3,4,1 zero epithelial\r\n#####                  : Changed 0 to 1 in field 6 of sample 1219406\r\n#####                  : Changed 0 to 1 in field 8 of following sample:\r\n#####                  : 1182404,2,3,1,1,1,2,0,1,1,1", 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': '1. Sample code number:            id number\r\n2. Clump Thickness:               1 - 10\r\n3. Uniformity of Cell Size:       1 - 10\r\n4. Uniformity of Cell Shape:      1 - 10\r\n5. Marginal Adhesion:             1 - 10\r\n6. Single Epithelial Cell Size:   1 - 10\r\n7. Bare Nuclei:                   1 - 10\r\n8. Bland Chromatin:               1 - 10\r\n9. Normal Nucleoli:               1 - 10\r\n10. Mitoses:                       1 - 10\r\n11. Class:                        (2 for benign, 4 for malignant)', 'citation': None}}
#                            name     role         type demographic  \
# 0            Sample_code_number       ID  Categorical        None
# 1               Clump_thickness  Feature      Integer        None
# 2       Uniformity_of_cell_size  Feature      Integer        None
# 3      Uniformity_of_cell_shape  Feature      Integer        None
# 4             Marginal_adhesion  Feature      Integer        None
# 5   Single_epithelial_cell_size  Feature      Integer        None
# 6                   Bare_nuclei  Feature      Integer        None
# 7               Bland_chromatin  Feature      Integer        None
# 8               Normal_nucleoli  Feature      Integer        None
# 9                       Mitoses  Feature      Integer        None
# 10                        Class   Target       Binary        None
#
#                   description units missing_values
# 0                        None  None             no
# 1                        None  None             no
# 2                        None  None             no
# 3                        None  None             no
# 4                        None  None             no
# 5                        None  None             no
# 6                        None  None            yes
# 7                        None  None             no
# 8                        None  None             no
# 9                        None  None             no
# 10  2 = benign, 4 = malignant  None             no
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1700431729.786341       1 tfrt_cpu_pjrt_client.cc:349] TfrtCpuClient created.

# %%
X.shape, y.shape
# Out:
# ((683, 9), (683, 1))

# %%
from jax import jit, grad, lax


@jit
def sigmoid(x: np.ndarray) -> np.ndarray:
    return 1 / (1 + np.exp(-x))


@jit
def log_pred(beta: np.ndarray, X: np.ndarray) -> np.ndarray:
    print(X)
    print(beta)
    print(beta.shape, X.shape)
    return sigmoid(np.dot(X, beta))


@jit
def log_loss(
    inputs: np.ndarray, targets: np.ndarray, weights: np.ndarray, lmbda: float = 0
) -> float:
    pred = log_pred(weights, inputs)
    label_probs = pred * targets + (1 - pred) * (1 - targets)
    return (
        -np.sum(np.log(label_probs + 1e-7))
        + lmbda * np.dot(weights.T, weights).squeeze()
    )

# %%
from Gradients import Gradients
from Schedules import Constant, Adagrad

grads = Gradients(
    X.shape[0], X, y, log_loss, polynomial=False, scheduler=Adagrad(0.001), lmbda=1
)

# %%
onp.random.seed(2023)
# beta = onp.random.randn(X.shape[1], 1)
beta = np.zeros((X.shape[1], 1))

beta_fix = grads.StochasticGradientDescent(beta, 50, 50)
# Out:
# Traced<ShapedArray(float32[50,9])>with<DynamicJaxprTrace(level=5/0)>
# Traced<ShapedArray(float32[9,1])>with<DynamicJaxprTrace(level=5/0)>
# (9, 1) (50, 9)
# Traced<ShapedArray(float32[683,9])>with<DynamicJaxprTrace(level=2/0)>
# Traced<ShapedArray(float32[9,1])>with<DynamicJaxprTrace(level=2/0)>
# (9, 1) (683, 9)

# %%
np.sum((log_pred(beta_fix, X) > 0.5) == y) / y.size
# Out:
# Array(0.8579795, dtype=float32)

# %%
final_pred = log_pred(beta_fix, X) > 0.5

# %%
np.sum(np.abs(final_pred - y))
# Out:
# Array(97., dtype=float32)

# %%
np.dot(beta.T, beta).squeeze()
# Out:
# Array(0., dtype=float32)

# %%
from grad_analysis import GradAnalysis
from pathlib import Path

basePath = Path.cwd().parent.parent / "figures/logreg"
basePath.mkdir(parents=True, exist_ok=True)

GA = GradAnalysis(
    X,
    y,
    100,
    2023,
    log_loss,
    base_theta=beta,
    lmbda=0.001,
    figspath=basePath,
    polynomial=False,
)

# %%
GA.minibatch_analysis(8)
# Out:
# /Users/augustfemtehjell/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/numpy/reductions.py:230: UserWarning: Explicitly requested dtype <class 'numpy.int64'> requested in prod is not available, and will be truncated to dtype int32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return _reduction(a, "prod", np.prod, lax.mul, 1, preproc=_cast_to_numeric,
# Traced<ShapedArray(float32[100,9])>with<DynamicJaxprTrace(level=5/0)>
# Traced<ShapedArray(float32[9,1])>with<DynamicJaxprTrace(level=5/0)>
# (9, 1) (100, 9)
# Traced<ShapedArray(float32[99,9])>with<DynamicJaxprTrace(level=5/0)>
# Traced<ShapedArray(float32[9,1])>with<DynamicJaxprTrace(level=5/0)>
# (9, 1) (99, 9)
# Traced<ShapedArray(float32[98,9])>with<DynamicJaxprTrace(level=5/0)>
# Traced<ShapedArray(float32[9,1])>with<DynamicJaxprTrace(level=5/0)>
# (9, 1) (98, 9)
# Traced<ShapedArray(float32[97,9])>with<DynamicJaxprTrace(level=5/0)>
# Traced<ShapedArray(float32[9,1])>with<DynamicJaxprTrace(level=5/0)>
# (9, 1) (97, 9)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/dtypes.py:591, in dtype(x, canonicalize)
#     590 try:
# --> 591   dt = np.result_type(x)
#     592 except TypeError as err:
#
# TypeError: Cannot interpret 'Array([174,  94, 333, 681, 621, 561, 171, 376, 503, 134, 484, 256, 337,
#        672, 276, 111, 479, 634,   5,   3, 140, 240, 433, 292, 635,  82,
#        673, 167, 237, 355, 621, 271, 234, 315, 367, 579, 593, 645,  31,
#         56, 649, 680, 389, 489, 379, 548, 502, 453,  73, 522, 485, 124,
#        443, 392,  14, 575, 551, 287, 250, 555, 166, 175, 420, 514, 153,
#        552, 536,  37, 659, 432, 357,  27, 675, 428, 582, 300, 513, 494,
#        432, 492, 547, 192,  44, 244, 341, 109, 474, 668, 613, 650,   8,
#        176, 127, 101, 382, 253, 626], dtype=int32)' as a data type
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /Users/augustfemtehjell/Documents/Høst23/FYSSTK/Project2/src/jupyter_analysis/logistic_regression.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/augustfemtehjell/Documents/H%C3%B8st23/FYSSTK/Project2/src/jupyter_analysis/logistic_regression.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> GA.minibatch_analysis(8)
#
# File ~/Documents/Høst23/FYSSTK/Project2/src/grad_analysis.py:731, in GradAnalysis.minibatch_analysis(self, dim)
#     717     schedule = TimeDecay(1, 10, batch_size)
#     718     Gradient = Gradients(
#     719         self.n_points,
#     720         self.x_vals,
#    (...)
#     726         polynomial=self.polynomial,
#     727     )
#     728     theta_arr = assign_row(
#     729         theta_arr,
#     730         i,
# --> 731         Gradient.StochasticGradientDescent(
#     732             self.base_theta, 150, batch_size
#     733         ).ravel(),
#     734     )
#     736     error_arr = assign_row(error_arr, i, Gradient.errors)
#     738 pred_arr = self.pred_per_theta(self.base_x, theta_arr, dim)
#
# File ~/Documents/Høst23/FYSSTK/Project2/src/Gradients.py:148, in Gradients.StochasticGradientDescent(self, theta, n_epochs, M)
#     146 idxs = np.random.choice(self.n, M)
#     147 xi = self.X[idxs]
# --> 148 yi = self.y[idxs]
#     150 gradients = self.gradient(xi, yi, theta, self.lmbda)
#     151 change = self.scheduler.update_change(gradients)
#
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/array.py:319, in ArrayImpl.__getitem__(self, idx)
#     317   return lax_numpy._rewriting_take(self, idx)
#     318 else:
# --> 319   return lax_numpy._rewriting_take(self, idx)
#
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:4291, in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    4288       return lax.dynamic_index_in_dim(arr, idx, keepdims=False)
#    4290 treedef, static_idx, dynamic_idx = _split_index_for_jit(idx, arr.shape)
# -> 4291 return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    4292                unique_indices, mode, fill_value)
#
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:4300, in _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, fill_value)
#    4297 def _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    4298             unique_indices, mode, fill_value):
#    4299   idx = _merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# -> 4300   indexer = _index_to_gather(shape(arr), idx)  # shared with _scatter_update
#    4301   y = arr
#    4303   if fill_value is not None:
#
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:4475, in _index_to_gather(x_shape, idx, normalize_indices)
#    4472 ndim = len(shape)
#    4474 start_dim = len(gather_indices_shape)
# -> 4475 gather_indices += ((lax.convert_element_type(a, index_dtype), start_dim)
#    4476                    for a in advanced_indexes)
#    4477 gather_indices_shape += shape
#    4479 start_index_map.extend(x_advanced_axes)
#
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:4475, in <genexpr>(.0)
#    4472 ndim = len(shape)
#    4474 start_dim = len(gather_indices_shape)
# -> 4475 gather_indices += ((lax.convert_element_type(a, index_dtype), start_dim)
#    4476                    for a in advanced_indexes)
#    4477 gather_indices_shape += shape
#    4479 start_index_map.extend(x_advanced_axes)
#
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/lax/lax.py:513, in convert_element_type(operand, new_dtype)
#     498 def convert_element_type(operand: ArrayLike, new_dtype: DTypeLike) -> Array:
#     499   """Elementwise cast.
#     500
#     501   Wraps XLA's `ConvertElementType
#    (...)
#     511     An array with the same shape as `operand`, cast elementwise to `new_dtype`.
#     512   """
# --> 513   return _convert_element_type(operand, new_dtype, weak_type=False)
#
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/lax/lax.py:527, in _convert_element_type(operand, new_dtype, weak_type)
#     522   return convert_element_type_p.bind(operand, new_dtype=new_dtype,
#     523                                      weak_type=bool(weak_type))
#     525 # Don't canonicalize old_dtype because x64 context might cause
#     526 # un-canonicalized operands to be passed in.
# --> 527 old_dtype = dtypes.dtype(operand, canonicalize=False)
#     528 old_weak_type = dtypes.is_weakly_typed(operand)
#     529 if new_dtype is None:
#
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/dtypes.py:593, in dtype(x, canonicalize)
#     591     dt = np.result_type(x)
#     592   except TypeError as err:
# --> 593     raise TypeError(f"Cannot determine dtype of {x}") from err
#     594 if dt not in _jax_dtype_set and not issubdtype(dt, extended):
#     595   raise TypeError(f"Value '{x}' with dtype {dt} is not a valid JAX array "
#     596                   "type. Only arrays of numeric types are supported by JAX.")
#
# TypeError: Cannot determine dtype of [174  94 333 681 621 561 171 376 503 134 484 256 337 672 276 111 479 634
#    5   3 140 240 433 292 635  82 673 167 237 355 621 271 234 315 367 579
#  593 645  31  56 649 680 389 489 379 548 502 453  73 522 485 124 443 392
#   14 575 551 287 250 555 166 175 420 514 153 552 536  37 659 432 357  27
#  675 428 582 300 513 494 432 492 547 192  44 244 341 109 474 668 613 650
#    8 176 127 101 382 253 626]

# %%
GA.gd_main(8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/augustfemtehjell/Documents/Høst23/FYSSTK/Project2/src/jupyter_analysis/logistic_regression.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/Users/augustfemtehjell/Documents/H%C3%B8st23/FYSSTK/Project2/src/jupyter_analysis/logistic_regression.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> GA.gd_main(8)
#
# File ~/Documents/Høst23/FYSSTK/Project2/src/grad_analysis.py:856, in GradAnalysis.gd_main(self, dim)
#     854 eta_num = 75
#     855 eta_arr = np.logspace(-5, -1, eta_num)
# --> 856 self.constant_analysis(eta_arr, dim)
#     858 rho_num = 75
#     859 rho_arr = np.linspace(1 / self.n_points, 1, rho_num)
#
# File ~/Documents/Høst23/FYSSTK/Project2/src/grad_analysis.py:183, in GradAnalysis.constant_analysis(self, eta_vals, dim)
#     181 schedulers = [Constant(eta) for eta in eta_vals]
#     182 theta_arr, error_arr = self.error_and_theta_vals_gd(schedulers, dim)
# --> 183 pred_arr = self.pred_per_theta(self.base_x, theta_arr, dim)
#     185 PlotErrorPerVariable(
#     186     error_arr,
#     187     eta_vals,
#    (...)
#     192     saveName="constant_error",
#     193 )
#     194 PlotPredictionPerVariable(
#     195     self.base_x,
#     196     pred_arr,
#    (...)
#     204     saveName="constant_prediction",
#     205 )
#
# File ~/Documents/Høst23/FYSSTK/Project2/src/grad_analysis.py:144, in GradAnalysis.pred_per_theta(self, x, theta_arr, dim)
#     133 DummyGrad = Gradients(
#     134     self.n_points,
#     135     self.x_vals,
#    (...)
#     141     polynomial=self.polynomial,
#     142 )
#     143 for i, theta in enumerate(theta_arr):
# --> 144     pred_arr = assign_row(pred_arr, i, DummyGrad.predict(x, theta, dim))
#     146 return pred_arr
#
#     [... skipping hidden 12 frame]
#
# File ~/Documents/Høst23/FYSSTK/Project2/src/utils.py:14, in assign_row(arr, idx, val)
#      12 @jit
#      13 def assign_row(arr, idx, val):
# ---> 14     arr = arr.at[idx, :].set(val)
#      15     return arr
#
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:482, in _IndexUpdateRef.set(self, values, indices_are_sorted, unique_indices, mode)
#     473 def set(self, values, *, indices_are_sorted=False, unique_indices=False,
#     474         mode=None):
#     475   """Pure equivalent of ``x[idx] = y``.
#     476
#     477   Returns the value of ``x`` that would result from the NumPy-style
#    (...)
#     480   See :mod:`jax.ops` for details.
#     481   """
# --> 482   return scatter._scatter_update(self.array, self.index, values, lax.scatter,
#     483                                  indices_are_sorted=indices_are_sorted,
#     484                                  unique_indices=unique_indices, mode=mode)
#
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/ops/scatter.py:78, in _scatter_update(x, idx, y, scatter_op, indices_are_sorted, unique_indices, mode, normalize_indices)
#      75 # XLA gathers and scatters are very similar in structure; the scatter logic
#      76 # is more or less a transpose of the gather equivalent.
#      77 treedef, static_idx, dynamic_idx = jnp._split_index_for_jit(idx, x.shape)
# ---> 78 return _scatter_impl(x, y, scatter_op, treedef, static_idx, dynamic_idx,
#      79                      indices_are_sorted, unique_indices, mode,
#      80                      normalize_indices)
#
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/ops/scatter.py:112, in _scatter_impl(x, y, scatter_op, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, normalize_indices)
#     109 x, y = promote_dtypes(x, y)
#     111 # Broadcast `y` to the slice output shape.
# --> 112 y = jnp.broadcast_to(y, tuple(indexer.slice_shape))
#     113 # Collapse any `None`/`jnp.newaxis` dimensions.
#     114 y = jnp.squeeze(y, axis=indexer.newaxis_dims)
#
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:1194, in broadcast_to(array, shape)
#    1190 @util._wraps(np.broadcast_to, lax_description="""\
#    1191 The JAX version does not necessarily return a view of the input.
#    1192 """)
#    1193 def broadcast_to(array: ArrayLike, shape: Shape) -> Array:
# -> 1194   return util._broadcast_to(array, shape)
#
# File ~/opt/miniconda3/envs/fysstk/lib/python3.11/site-packages/jax/_src/numpy/util.py:402, in _broadcast_to(arr, shape)
#     400 if nlead < 0 or not compatible:
#     401   msg = "Incompatible shapes for broadcasting: {} and requested shape {}"
# --> 402   raise ValueError(msg.format(arr_shape, shape))
#     403 diff, = np.where(tuple(not core.definitely_equal(arr_d, shape_d)
#     404                        for arr_d, shape_d in safe_zip(arr_shape, shape_tail)))
#     405 new_dims = tuple(range(nlead)) + tuple(nlead + diff)
#
# ValueError: Incompatible shapes for broadcasting: (100,) and requested shape (683,)

# %%
from utils import assign_row
from plotutils import PlotErrorPerVariable
from Schedules import Constant, Momentum, Adagrad, AdagradMomentum, Adam, RMS_prop

eta_num = 75
n_epochs = 40

BaseSchedules = [Constant, Momentum, Adagrad, AdagradMomentum, Adam, RMS_prop]
schedule_params = [(), (0.9,), (), (0.9,), (0.9, 0.999), (0.9,)]
eta_bounds = [(-6, -4), (-6, -4), (-4, -2), (-4, -2), (-4, -2), (-4, -2)]
# schedulers = [Adam(eta, 0.9, 0.999) for eta in eta_arr]
base_beta = np.zeros((X.shape[1], 1))

for BaseSchedule, params, eta_bound in zip(BaseSchedules, schedule_params, eta_bounds):
    lower, upper = eta_bound
    eta_arr = np.logspace(lower, upper, eta_num)
    schedulers = [BaseSchedule(eta, *params) for eta in eta_arr]
    error_arr_sgd = np.zeros((eta_num, n_epochs))
    error_arr_gd = np.zeros((eta_num, n_epochs * 3))
    beta_arr = np.zeros((eta_num, X.shape[1]))

    for i, schedule in enumerate(schedulers):
        Gradient = Gradients(
            X.shape[0],
            X,
            y,
            log_loss,
            scheduler=schedule,
            lmbda=0.1,
            polynomial=False,
        )
        beta_arr = assign_row(
            beta_arr,
            i,
            Gradient.StochasticGradientDescent(base_beta, n_epochs, 100).ravel(),
        )
        error_arr_sgd = assign_row(
            error_arr_sgd,
            i,
            Gradient.errors,
        )
        Gradient = Gradients(
            X.shape[0],
            X,
            y,
            log_loss,
            scheduler=schedule,
            lmbda=0.1,
            polynomial=False,
        )
        beta_arr = assign_row(
            beta_arr,
            i,
            Gradient.GradientDescent(base_beta, n_epochs * 3).ravel(),
        )
        error_arr_gd = assign_row(
            error_arr_gd,
            i,
            Gradient.errors,
        )
    PlotErrorPerVariable(
        error_arr_sgd,
        eta_arr,
        figsPath=basePath,
        error_label="LogReg",
        error_type="linear",
        colormap="viridis",
        title=f"SGD of LogReg with {BaseSchedule.__name__} Schedule",
        savePlots=True,
        saveName=f"LogReg_{BaseSchedule.__name__}_error_sgd",
    )
    PlotErrorPerVariable(
        error_arr_gd,
        eta_arr,
        figsPath=basePath,
        error_label="LogReg",
        error_type="linear",
        colormap="viridis",
        title=f"GD of LogReg with {BaseSchedule.__name__} Schedule",
        savePlots=True,
        saveName=f"LogReg_{BaseSchedule.__name__}_error_gd",
    )
    print("Done with ", BaseSchedule)
# for i, schedule in enumerate(schedulers):
#     Gradient = Gradients(
#         X.shape[0],
#         X,
#         y,
#         log_loss,
#         scheduler=schedule,
#         lmbda=0.1,
#         polynomial=False,
#     )

#     beta_arr = assign_row(
#         beta_arr,
#         i,
#         Gradient.StochasticGradientDescent(base_beta, n_epochs, 50).ravel(),
#     )

#     error_arr = assign_row(error_arr, i, Gradient.errors)
# Out:
# Done with  <class 'Schedules.Constant'>
# Done with  <class 'Schedules.Momentum'>
# Done with  <class 'Schedules.Adagrad'>
# Done with  <class 'Schedules.AdagradMomentum'>
# Done with  <class 'Schedules.Adam'>
# Done with  <class 'Schedules.RMS_prop'>

# %%
Gradient = Gradients(
    X.shape[0],
    X,
    y,
    log_loss,
    scheduler=Adam(0.001, 0.9, 0.999),
    lmbda=0.1,
    polynomial=False,
)
beta = Gradient.GradientDescent(base_beta, 1000)

# %%
np.mean((log_pred(beta, X) > 0.5) == y)
# Out:
# Array(0.86237186, dtype=float32)

# %%
error_arr
# Out:
# Array([[ 461.8559 ,  454.47617,  449.48856, ...,  333.88922,  333.5535 ,
#          333.2204 ],
#        [ 460.5258 ,  452.8003 ,  447.7859 , ...,  327.73795,  327.41068,
#          327.08606],
#        [ 459.07605,  451.08002,  446.09283, ...,  321.76138,  321.4447 ,
#          321.13083],
#        ...,
#        [7156.4365 , 7156.4365 , 7156.4365 , ..., 7156.4365 , 7156.4365 ,
#         7156.4365 ],
#        [7156.4365 , 7156.4365 , 7156.4365 , ..., 7156.4365 , 7156.4365 ,
#         7156.4365 ],
#        [7156.4365 , 7156.4365 , 7156.4365 , ..., 7156.4365 , 7156.4365 ,
#         7156.4365 ]], dtype=float32)

# %%
from plotutils import plotThetas

plotThetas(beta_arr, eta_arr, figsPath=basePath, colormap="viridis_r")
